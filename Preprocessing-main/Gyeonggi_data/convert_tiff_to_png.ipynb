# %%
import os
from PIL import Image

yourpath = os.getcwd()
for root, dirs, files in os.walk(yourpath, topdown=False):
    for name in files:
        print(os.path.join(root, name))
        if os.path.splitext(os.path.join(root, name))[1].lower() == ".tif":
            if os.path.isfile(os.path.splitext(os.path.join(root, name))[0] + ".png"):
                print ("A png file already exists for %s" % name)
            # If a PNG is *NOT* present, create one from the tiff.
            else:
                outfile = os.path.splitext(os.path.join(root, name))[0] + ".png"
                try:
                    im = Image.open(os.path.join(root, name))
                    print("Generating jpeg for %s" % name)
                    im.thumbnail(im.size)
                    im.save(outfile, "png", quality=100)
                except Exception as e:
                    print (e)
# Out:
# /home/aiffel-dj10/Seoul_dataset/.ipynb_checkpoints/BnR_list-checkpoint.ipynb
# /home/aiffel-dj10/Seoul_dataset/.ipynb_checkpoints/change_json_name-checkpoint.ipynb
# /home/aiffel-dj10/Seoul_dataset/.ipynb_checkpoints/labelling-checkpoint.ipynb
# /home/aiffel-dj10/Seoul_dataset/.ipynb_checkpoints/parsing_building_sangmin_train-checkpoint.ipynb
# /home/aiffel-dj10/Seoul_dataset/.ipynb_checkpoints/making_label-checkpoint.ipynb
# /home/aiffel-dj10/Seoul_dataset/.ipynb_checkpoints/convert_tiff_to_png-checkpoint.ipynb
# /home/aiffel-dj10/Seoul_dataset/train/image/LC_AP_37710099_018_1024.tif
# Generating jpeg for LC_AP_37710099_018_1024.tif
# /home/aiffel-dj10/Seoul_dataset/train/image/LC_AP_37607057_013_1024.tif
# Generating jpeg for LC_AP_37607057_013_1024.tif
# /home/aiffel-dj10/Seoul_dataset/train/image/LC_AP_37711082_019_1024.tif
# Generating jpeg for LC_AP_37711082_019_1024.tif
# /home/aiffel-dj10/Seoul_dataset/train/image/LC_AP_37615029_013_1024.tif
# ...

# %%
import cv2
import glob
from matplotlib import pyplot as plt

# %%
tif_path = '/home/aiffel-dj10/Seoul_dataset/train/image/LC_AP_37607046_001_1024.tif'
png_path = '/home/aiffel-dj10/Seoul_dataset/val/image/LC_AP_37607046_001_1024.png'

img_path = '/home/aiffel-dj10/Seoul_dataset/train/image/'

# %%
image_files = glob.glob(img_path + '*.tif')
len(image_files)
# Out:
# 2640

# %%
img = cv2.imread(tif_path)
print(img.min(), img.max())
plt.imshow(img)
# Out:
# 17 253

# %%
import tifffile as tiff
a = tiff.imread(tif_path)
a.shape, type(a)
# Out:
# ((1024, 1024, 3), numpy.ndarray)

# %%
a.min(), a.max()
# Out:
# (17, 253)

# %%
# 채널 값 normalization : 0-1 사이로.
# 학습 시 이미지 데이터는 0-1 사이로 정규화해서 모델에 입력한다. 
a = (a - a.min()) / (a.max() - a.min())

a = a.astype('float64')
a /= a.max()/255.0
a.min(), a.max()
# Out:
# (0.0, 255.0)

# %%
a = a.astype('uint8')
type(a)
# Out:
# numpy.ndarray

# %%
from matplotlib import pyplot as plt

plt.imshow(a)

# %%
import numpy as np 
from PIL import Image 
import matplotlib.pyplot as plt 
from matplotlib import cm

for i in image_files:
    save_path = i.split('.')[0]
    i = tiff.imread(i)
    # 채널 값 normalization : 0-1 사이로.
    # 학습 시 이미지 데이터는 0-1 사이로 정규화해서 모델에 입력한다. 
    i = (i - i.min()) / (i.max() - i.min())
    a = i.astype('float64')
    a /= a.max()/255.0
    a = a.astype('uint8')
    image = Image.fromarray(a)
    image.save(f'{save_path}.png')
    print(a.min(), a.max())
# Out:
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# 0 255
# ...

# %%
import cv2

img = cv2.imread('/home/aiffel-dj10/SIAiffel_JJeonda/SIAiffel/datasets/data/SIA/multi/gtFine/train/train/BLD00001_PS3_K3A_NIA0276.png')
print(img.min(), img.max())
plt.imshow(img)
# Out:
# 0 255

# %%
plt.imshow(img)

# %%
img_scaled = cv2.normalize(img, dst=None, alpha=24, beta=253, norm_type=cv2.NORM_MINMAX)
plt.imshow(img_scaled)

# %%
img_scaled = cv2.normalize(img, dst=None, alpha=30, beta=40, norm_type=cv2.NORM_MINMAX)
plt.imshow(img_scaled)

# %%
img.min(), img.max(), img.shape, type(img)
# Out:
# (24, 253, (1024, 1024, 3), numpy.ndarray)
